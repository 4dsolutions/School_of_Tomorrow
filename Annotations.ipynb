# %% [markdown]
# [Oregon Curriculum Network](http://4dsolutions.net/ocn/)
#
# [School of Tomorrow (Home)](School_of_Tomorrow.ipynb)
#
#
# # Christmas 2025: Scholarship in Action

# %% [markdown]
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55005469522/in/photostream/" title="Screen Shot 2025-12-26 at 8.22.31 AM"><img src="https://live.staticflickr.com/65535/55005469522_e5025a83cf.jpg" width="431" height="500" alt="Screen Shot 2025-12-26 at 8.22.31 AM"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %% [markdown]
# Would you believe this is a Christmas Day, and I'm just doing this as a fun passtime?
#
# For me, Xmas is about reaping the benefits of scholarship, which in a way is what any religion is about, that wants to give its practicioners a safe space to just explore their world, or "engage in epistemic foraging" as we Wanderers say.
#
# You don't have to pick up the sword of some emperor, let alone some feudal lord, and engage in temporal battles on their behalf.
#
# Rather, why not study the Python type specification system, added incrementally over time to a dynamic language that once prided itself, and still does, on making type specifications superfluous (as in unnecessary).
#
# That a feature is inessential and even an unwanted burden in some circumstances, doesn't mean at other times it can't be a boon.
#
# I've grown up in the habit of not needing any typing specifications and thinking of them as unnecessary clutter.
#
# Rather than let such habits calcify into defended dogmas (wasted energy really) I'll spend some energy anticipatorily to upgrade my fluency around Python, using one of my favorite texts, [<i>Python in a Nutshell</i>](https://learning.oreilly.com/library/view/python-in-a/9781098113544/).

# %% [markdown]
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55005219204/in/dateposted/" title="Screen Shot 2025-12-25 at 11.24.04 AM"><img src="https://live.staticflickr.com/65535/55005219204_196731cd49.jpg" width="500" height="281" alt="Screen Shot 2025-12-25 at 11.24.04 AM"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %% [markdown]
# The fourth edition has Steve Holden's name on it.
#
# Steve and I were ["partners in crime"](https://mybizmo.blogspot.com/2011/09/my-character.html) back in the [DjangoCon days](https://controlroom.blogspot.com/2010/09/serendipitous-opportunity.html), when his Open Bastion produced that and several other techno-geek conferences.
#
# Steve and I were also co-workers through O'Reilly Media, back when it was running an experimental code school, the O'Reilly School of Technology (OST or SOT).  He was the author of the Python 3 curriculum I was teaching, to eager students online.

# %% [markdown]
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/51860825059/" title="O&#x27;Reilly School of Technology Business Card"><img src="https://live.staticflickr.com/65535/51860825059_f0067c828a.jpg" width="500" height="299" alt="O&#x27;Reilly School of Technology Business Card"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %%
import typing
from typing import Annotated, get_type_hints

# %%
def repeater(s : Annotated[str, "template"], 
             x : Annotated[int, "times to repeat"]) -> str:
    return x * s

# %%
repeater("K", 10)
# Out:
# 'KKKKKKKKKK'

# %%
repeater("K", 0)
# Out:
# ''

# %%
repeater("KO", 2)
# Out:
# 'KOKO'

# %%
anno_dict = get_type_hints(repeater, include_extras = True)
anno_dict
# Out:
# {'s': typing.Annotated[str, 'template'],
#  'x': typing.Annotated[int, 'times to repeat'],
#  'return': str}

# %%
get_type_hints(repeater, include_extras = False)
# Out:
# {'s': str, 'x': int, 'return': str}

# %%
type(anno_dict['x'])
# Out:
# typing._AnnotatedAlias

# %%
anno_dict['x'].__dict__
# Out:
# {'_inst': True,
#  '_name': None,
#  '__origin__': int,
#  '__slots__': None,
#  '__args__': (int,),
#  '__parameters__': (),
#  '_paramspec_tvars': False,
#  '__module__': 'builtins',
#  '__metadata__': ('times to repeat',)}

# %% [markdown]
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/6131322017/in/photolist-ojM4Lv-akNCqz-brQnm3-cPUXyj-dNhhyF-dXHgrf-fGFXT2" title="The Open Bastion"><img src="https://live.staticflickr.com/6201/6131322017_4d097d424f.jpg" width="500" height="375" alt="The Open Bastion"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

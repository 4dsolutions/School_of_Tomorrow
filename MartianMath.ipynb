# %% [markdown]
# [Oregon Curriculum Network](http://4dsolutions.net/ocn/)
#
# # Martian Math
#
# * [Martian Math as a part of a Digital Mathematics Curriculum](https://wikieducator.org/Martian_Math) (WikiEducator)
# * [Storyboard Ideas on Flickr](https://flic.kr/s/aHsjrM3Fho) (Photo Album)
# * [Example Pilot Course at Reed College](https://github.com/4dsolutions/MartianMath/blob/master/mm1.ipynb) (Jupyter Notebooks)
# * [Three Phase Power](https://github.com/4dsolutions/SAISOFT/blob/master/ThreePhasePower.ipynb)  (Jupyter Notebook)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("x6Dv0rwTSS8")

# %%
YouTubeVideo("kBjZb-RrgLY")

# %% [markdown]
# * [Silicon Forest: Neolithic Math](https://wikieducator.org/Neolithic_Math)
# * [School of Tomorrow](https://4dsolutions.github.io/School_of_Tomorrow/)
#
#
# ### Looking Back...
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/54191289184/in/dateposted/" title="Art Deco Style"><img src="https://live.staticflickr.com/65535/54191289184_619a93c574_c.jpg" width="800" height="800" alt="Art Deco Style"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# ### Research Topics:
#
# **Aesthetics**:
#
# * [King Tut and the Desert Roots of Art Deco](https://www.colorandmirror.com/egypt-and-art-deco)
# * [Egyptomania - The Egyptian Influence on Art Deco](https://canonburyantiques.com/kbd/Egyptomania-The-Egyptian-Influence-on-Art-Deco/)

# %% [markdown]
# **Mathematics**:
#
# Going back now to the mathematics of ancient Egypt, Milo Gardner sent the following:
#
# <blockquote>
# The purpose of this narrative is to outline meta Egyptian math topics that 21st century Egyptology scholars have not formally considered, and will not consider , until "pushed".
#
# Multiple Old Kingdom mythic metaphors, stated in the Book of the Dead , continued in the Middle Kingdom. Most were unchanged, and actively energized in both the Old and Middle Kingdoms.
#
# Egyptian scribes loved mythic and innovative math metaphors, developed in the Old Kingdom with both energized in the Middle Kingdom. Several math innovations in controlling the grain as wages were modified in unexpected ways.
#
# For example, the centralized, top down, Old Kingdom duplation multiplication definition , arguably the oldest multiplication definition, appeared as one of three multiplication definitions in the Middle Kingdom.
#
# The first Middle Kingdom duplation multiplication definition was modified in the Berlin Papyrus. An inverse proportion, based on the pesu likely assisted in.solving two second degree equations. The inverse proportion unit was detected by Schackenberg (1900), asks several questions
# that Egyptologists need to try to answer.
#
# It is well kniwn.that Archimedes and Greeks used inverse proportion to approximate the square root of prime numbers , such as the square root of three, needed to extend the upper and lower limits of pi from 22/7. But, was the Greek inverse proportion method passed down from Egyptian sources. Ahmes may have improved pi = 256/81 understood pi = 22/7 , in RMP 38 reported
#
# 320/320 x 7/22 = (101 + 9/11)(1/320)) x 22/7
#
# A second definition is found in the Akhmim
# Wooden Tablet and dozens of RMP problems. These problems were read by 20th century scholars as only Middle Kingdom duplation multiplication initial calculations , not noticing several final answers explicitly appeared in problem question statements . Statements
# and proofs followed the well known modem
# number theory axiom, multiplication and
# division were fully inverse to one another.
#
# A third multiplication definition applied least common multiples (LCMsl as scaling factors to 2/table unit fraction series answers.the LCMs appeared in denominators and were larger than expected for 20th century scholars that randomly segmented 2/n table conversions to unit fraction series into three classes.
#
# Actually , there was only one class of LCM
# scaling factors selected in 2/n table unit
# fraction series.
#
# For example , scribes solved 2/91 by subtracting 1/70 ( used LCM 70) by same method used in every RMP and KP 2/n table concise unit fraction series answer.
#
# 2/91 = (2/91 - 1/70) = (140 - 91)/(70)(91)
# = 1/70 + 1/130
#
# Scribes also mentally considered a third multiplication definition, with each LCM stated as a scaling factor (m/m) per:
#
# 2/n (m/m) = (2mn - n)/mn
#
# The best divisors of mn were summed to (2m-n) by red auxiliary numbers.
#
# Example:
# 2/43 = 2/43*(42/42)=(43 + 21 + 14 + 6)/1806 = 1/42 + 1/86 + 1/129 + 1/301
#
# The multiplication definition utilized prime numbers , a well known number theory idea (Oystein Ore, "Number Theory and its History , 1948).
#
# Searching for an Old Kingdom arithmetic metaphor that had been first written down within irrational planetary cycles, and approximated within an explicit recursive base10 numeration system, opens several
# doors.
#
# One well known door exposed infinite series predicates (questions) that were written down in the Eye of Horus notation:
# 1 = 1/2 + 1/4 + 1/8 + 1/16 + 1/32 + 1/64
#
# What is not well known is that a finite base 10 solution was published in the Akhmim Wooden Tablet, stated with a volume unit context.The 1925 BCE AWT text was often ignored in the Cairo Museum from 1906 until 2002. The AWT was freshly photographed and analyzed by Hana Vymazalova in 2002 found that five divisions of one heqat by n = 3, 7, 10, 11, 13: restated to a multiplication context.
#
# All were exact, correcting Daressy (1906) that only found the n= 3, 7, 10 cases were exact, in a cubit context, amended by Peet (1923) to required ro = 1/320 of a heqat , a least common multiple (LCM).
# Quotient (Q) and Remainder (R) were scaled by 64/64 and 5/5 , respectively , one of several number theory facts were not reported in 2002.
#
# By 2014 is became clear to this researcher that the AWT was solved and proven by algebra, namely
#
# 64/64 x 1/n = (Q/64 + (5R/n)(1/320)) x n = 64/64
#
# The masters student in Egyptology at Charles U, Prague followed an 1920s tradition, omitted the number theory sides of the AWT in 2002, by titling the five proof calculations of 64/64 as heqat unity , ending her paper citing Peet.
#
# The 1920s traditional was formalized in 1927 by Shute, et al, by transliterating the RMP, and the EMLR by the British Museum by oddly concluding that Egyptian arithmetic was only additive in the minds of scribes, offering no review of 50 years of German, and British scholarship on the subject, that offered different points of view .
# Simply stated, Shute, et al , and BM scholars threw out all hints and fragments of number theory by following a well known adage " throw out the (number theory) baby with the bath water" whenever Egyptian arithmetic was recorded by an Egyptian scribe, citing single false position seemed insufficient to Schack Schackenberg (1900), Hultsch (1895), and Sylvester (1891, 1880), and concluded, with little evidence , that Egyptian division was limited to single false position.
#
# Nearing a concluding comment Egyptian math scholarship commenced in 1864, with Berlin Papyrus discussions, and a famous incident that reported Germans pirating a copy of the RMP, from the British Museum, and publishing it in 1879.
#
# A concluding meta comment : Old Kingdom Infinite series traditions were passed down to the Middle Kingdom were structured by infinite series questions and solved by finite unit series have been one of several serious number theory omissions in virtually all Egyptian math papers published in the
# 20th century. Much more calls out to be
# formally reported.
#
# Best Regards
# Milo Gardner,
# Cryptanalyst
# </blockquote>
#
# More context (Dec 8 2024):
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/54189809012/in/dateposted/" title="Egyptian Math"><img src="https://live.staticflickr.com/65535/54189809012_88da713f93.jpg" width="465" height="500" alt="Egyptian Math"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

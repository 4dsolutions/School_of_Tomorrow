# %% [markdown]
# [Oregon Curriculum Network](http://4dsolutions.net/ocn/)<br/>
# [School of Tomorrow](School_of_Tomorrow.ipynb)
#
# # MAPPING QUADRAYS
#
# This picture captures how I map BRYG, XYZ and IVM.
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55101865359/in/dateposted/" title="XYZ vs IVM"><img src="https://live.staticflickr.com/65535/55101865359_ebc8d93363_o.jpg" width="376" height="374" alt="XYZ vs IVM"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# The Red ball closest to camera is in the all-positives (x,y,z) octant. Vertical or Z-positive is black upwards, Y-positive is orange to the left, X-positive is magenta to the right.
#
# The green cube has face diagonals = 1, same length as the XYZ unit vectors. By changing the viewpoint (not the underlying coordinates) we can see BRY as a triangular base with G at the apex.
#
# This view, in contrast, is about thinking of XYZ in terms of its octants, and a center (origin) that corresponds to our Home Base Tetrahedron (HB4). Quadrays A, B, C, D are colored Red Green Blue Yellow.
#
# Let's change the camera position and fatten up the balls to be diameter D and therefore intertangent. This is a "home position" in terms of viewpoints, with Green the apex, Red the the left, Blue to the right, and Yellow behind them, resting on the same surface.
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55100920747/in/dateposted/" title="BRYG Viewpoint"><img src="https://live.staticflickr.com/65535/55100920747_645986676a_o.jpg" width="514" height="486" alt="BRYG Viewpoint"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %% [markdown]
# The animated GIF below, three flashcard PNGs, is from the py → pyc → pov → png → gif pipeline.

# %% [markdown]
# ![animated xyz-ivm](xyz_ivm_spokes.gif)

# %% [markdown]
# ## POV: Point of View
#
# Check out this scene description language for positioning the POV-Ray camera:
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55110934859/in/dateposted/" title="Screen Shot 2026-02-22 at 2.23.40 PM"><img src="https://live.staticflickr.com/65535/55110934859_570fa8ab3e_o.png" width="528" height="290" alt="Screen Shot 2026-02-22 at 2.23.40 PM"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# The location is in the (+x +y +z) direction, so into the all-positives Cartesian octant, with a look-back to the origin (close to it), but then we orbit the camera to bring the red-green cube face diagonal to the top. Here's the result:
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55110874263/in/dateposted/" title="test9_closeup_1"><img src="https://live.staticflickr.com/65535/55110874263_f96f732b10_o.jpg" width="514" height="485" alt="test9_closeup_1"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# Is this the most intuitive way of controlling the camera to render this vista?  Not necessarily.
#
# If you plan to dive into POV-Ray, you'll want to learn [more about controlling the camera](https://www.povray.org/documentation/view/3.60/246/).
#
# Next, lets render the exact same scene with no alterations other than repositioning the camera.
#
# This time we're going out the +Y axis and looking back, after rotating around the X and Z axes to get a better look:
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55110999530/in/photostream/" title="Screen Shot 2026-02-22 at 1.50.12 PM"><img src="https://live.staticflickr.com/65535/55110999530_5f8831ca1c_o.png" width="528" height="288" alt="Screen Shot 2026-02-22 at 1.50.12 PM"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# The rendered scene gives us a different perspective owing to the new camera position.  From here, we have a familiar arrangement:  blue left, red right, yellow back, green top.
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55110876584/in/dateposted/" title="test9_closeup_2"><img src="https://live.staticflickr.com/65535/55110876584_099cfce97f_o.jpg" width="513" height="486" alt="test9_closeup_2"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# We call this the BRYG viewpoint:
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55104257835/in/dateposted/" title="RGBY"><img src="https://live.staticflickr.com/65535/55104257835_b0f9a971b2_z.jpg" width="640" height="619" alt="RGBY"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %% [markdown]
# ## Python Code
#
# In the code cells below, we check the lengths and XYZ coordinates of the four quadrays, A, B, C, D, per our preferred color coding (Quadray Mapping).

# %%
from flextegrity import pov_header, Cuboctahedron, Cube, Octahedron, RT
from flextegrity import Tetrahedron, InvTetrahedron, RD, PD, Icosahedron, Mite
from flextegrity import Edge, draw_edge, draw_poly, draw_vert, half, ORIGIN, PHI
from qrays import Qvector, Vector, A, B, C, D

import numpy as np
import sympy as sy
import qrays
from sympy import sqrt as rt2, sin, cos
from mpmath import radians

# %%
(A-B).length()
# Out:
# 1

# %%
A.length()
# Out:
# sqrt(6)/4

# %%
A.length().evalf(50) # 50 decimals
# Out:
# 0.61237243569579452454932101867647284799148687016417

# %%
OZ = Vector((0,0,1))
OZ.length()
# Out:
# 1

# %% [markdown]
# How do the IVM balls, 12-around-1, then 42, 92, 162... in concentric layers, fit into this framework. The Red, Green, Blue, Yellow balls are at the centers intertangent IVM balls of diameter D = 1, Radius = 1/2.

# %%
qrays.DIAM, qrays.RAD
# Out:
# (1, 1/2)

# %%
A.xyz
# Out:
# xyz_vector(x=sqrt(2)/4, y=sqrt(2)/4, z=sqrt(2)/4)

# %%
B.xyz
# Out:
# xyz_vector(x=-sqrt(2)/4, y=-sqrt(2)/4, z=sqrt(2)/4)

# %%
C.xyz
# Out:
# xyz_vector(x=-sqrt(2)/4, y=sqrt(2)/4, z=-sqrt(2)/4)

# %%
D.xyz
# Out:
# xyz_vector(x=sqrt(2)/4, y=-sqrt(2)/4, z=-sqrt(2)/4)

# %% [markdown]
# Suppose we want to use Radius = 1, Diameter = 2. The framework allows this:

# %%
qrays.DIAM = 2; qrays.RAD = 1

# %% [markdown]
# The mapping to XYZ doesn't change, only distances, as now our Radius, still half the Diameter, gets to be unit:

# %%
A.xyz
# Out:
# xyz_vector(x=sqrt(2)/4, y=sqrt(2)/4, z=sqrt(2)/4)

# %%
A.length()
# Out:
# sqrt(6)/2

# %% [markdown]
# ## Gallery

# %% [markdown]
# Here's most of the Python script used to generate the POV-Ray scene description language responsible for the above image:
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55101604966/in/dateposted/" title="Script for a Rendering"><img src="https://live.staticflickr.com/65535/55101604966_2387e9a02e_z.jpg" width="623" height="640" alt="Script for a Rendering"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# Diagram: Mapping Quadrays to the Volume 3 Cube
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55100270115/in/dateposted/" title="BRYG"><img src="https://live.staticflickr.com/65535/55100270115_9a72f702af_z.jpg" width="640" height="480" alt="BRYG"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>
#
# <br />
#
# Development Environment: Asynchronous Comms + IDE
#
# <a data-flickr-embed="true" href="https://www.flickr.com/photos/kirbyurner/55109828472/in/dateposted/" title="Mapping Quadrays"><img src="https://live.staticflickr.com/65535/55109828472_f1fa46ec8f_z.jpg" width="640" height="547" alt="Mapping Quadrays"/></a><script async src="//embedr.flickr.com/assets/client-code.js" charset="utf-8"></script>

# %% [markdown]
# ## For Further Reading
#
# * [The QuadCraft Project](QuadCraft_Project.ipynb)
# * [Making Shapes](Shapes_Framework.ipynb)
# * [Vanes](Vanes.ipynb)
